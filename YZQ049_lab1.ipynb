# %% [markdown]
# Adrian Ramos YZQ049

# %% [markdown]
# # Lab 1 – Agents(Chatbot)

# %%
import random

#It is the hello message to get things going
print("Bot: Hello, I'm UTS-Bot. I'll be happy to help you.")

#this will contain the users input
user_input = input("You: ")

#It stands for first loop these are the loop variables so i can get out of them if need be
FirstL = 0

#The while loop that goes on infinetyl till inside the program changes it
while (FirstL < 1):

  #the if statment and else ifs for the diffrent hellos
  if user_input.lower() == "howdy":
    FirstL = 5
  elif user_input.lower() == "hello":
    FirstL = 5
  elif user_input.lower() == "sup":
    FirstL = 5
  elif user_input.lower() == "salutation":
    FirstL = 5
  elif user_input.lower() == "hi":
    FirstL = 5
  else:
    print("Bot: Hello, I'm UTS-Bot. I'll be happy to help you.")
    user_input = input("You: ")
  #if you dont put the right one it just states the intro again

#this is outside the loop and asks how you feel
print("Bot: How are you feeling today?")

#once again reads the uesrs input
user_input = input("You: ")

#once again the loop counter and a companion to see if you have a good responce or a bad one
SecondL = 0
Good2L=0

#INfinet loop till cahnged
while (SecondL < 1):

# these are the giid and bad responses you can give
  if user_input.lower() == "good":
    SecondL = 5
    Good2L = 1
  elif user_input.lower() == "great":
    SecondL = 5
    Good2L = 1
  elif user_input.lower() == "grand":
    SecondL = 5
    Good2L = 1
  elif user_input.lower() == "exelent":
    SecondL = 5
    Good2L = 1
  elif user_input.lower() == "swell":
    SecondL = 5
    Good2L = 1
  elif user_input.lower() == "bad":
    SecondL = 5
    Good2L = 2
  elif user_input.lower() == "unwell":
    SecondL = 5
    Good2L = 2
  elif user_input.lower() == "poor":
    SecondL = 5
    Good2L = 2
  elif user_input.lower() == "inferior":
    SecondL = 5
    Good2L = 2
  elif user_input.lower() == "substandard":
    SecondL = 5
    Good2L = 2
  else:
    print("Bot: How are you feeling today?")
    user_input = input("You: ")

#The rand to get the randomly selected response
RandN = random.randint(1, 5)
#Saves the rand for later use cause its going to be changes
Save = RandN
#THe loop variable again
ThirdL = 0
#The backup for the good ot bad response
Good2LBackup = Good2L
YesOrNo = 100

#infinet while loop till changed
while ThirdL < 1:
    #The main if statment for the random numbes 1 through 5 if its 1 a good or 2 a bad
    if Good2L == 1:
      #the randomly selected messages from the number 1 thorugh 5
      if RandN == 1:
        print("Bot: Thats good to hear. How can I help you today?")
        RandN = 20
      elif RandN == 2:
        print("Bot: Great to hear. How can I help you today?")
        RandN = 20
      elif RandN == 3:
        print("Bot: Awsome to hear. How can I help you today?")
        RandN = 20
      elif RandN == 4:
        print("Bot: Glad to hear that. How can I help you today?")
        RandN = 20
      elif RandN == 5:
        print("Bot: Wow thats kinda poggers. How can I help you today?")
        RandN = 20
    elif Good2L == 2:
      if RandN == 1:
        print("Bot: Hope you feel better. How can I help you today?")
        RandN = 20
      elif RandN == 2:
        print("Bot: Thats a shame. How can I help you today?")
        RandN = 20
      elif RandN == 3:
        print("Bot: Im sorry to hear that. How can I help you today?")
        RandN = 20
      elif RandN == 4:
        print("Bot: I hope i can improve it. How can I help you today?")
        RandN = 20
      elif RandN == 5:
        print("Bot: Wow thats not very pog. How can I help you today?")
        RandN = 20


    user_input = input("You: ")
# looks inside string and sees if the specified word is inside of it
    if 'uts-vdi' in user_input.lower():
      print("Bot: Did you say that you want to learn how to use UTS-VDI?")
      user_input = input("You: ")
      #if it is then you can say one of these responses to conrinue or restart
      if user_input.lower() == "yes":
        print("Bot: Please click on the following link (https://www.utsa.edu/techsolutions/students/software/vdi.html), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "yup":
        print("Bot: Please click on the following link (https://www.utsa.edu/techsolutions/students/software/vdi.html), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "yeah":
        print("Bot: Please click on the following link (https://www.utsa.edu/techsolutions/students/software/vdi.html), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "affirmative":
        print("Bot: Please click on the following link (https://www.utsa.edu/techsolutions/students/software/vdi.html), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "no":
        RandN = Save
        Good2L = Good2LBackup
      #THe aboveone is the restart one it takes it from the backups we made and made it so it loops like its new again and everyhitng from here is the same
    elif 'uts-vpn' in user_input.lower():
      print("Bot: Did you say that you want to learn how to use UTS-VPN?")
      user_input = input("You: ")
      if user_input.lower() == "yes":
        print("Bot: Please click on the following link (https://www.utsa.edu/techsolutions/docs/wireless/WhatUsesVPN.pdf), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "yup":
        print("Bot: Please click on the following link (https://www.utsa.edu/techsolutions/docs/wireless/WhatUsesVPN.pdf), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "yeah":
        print("Bot: Please click on the following link (https://www.utsa.edu/techsolutions/docs/wireless/WhatUsesVPN.pdf), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "affirmative":
        print("Bot: Please click on the following link (https://www.utsa.edu/techsolutions/docs/wireless/WhatUsesVPN.pdf), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "no":
        RandN = Save
        Good2L = Good2LBackup

    elif 'proctorio' in user_input.lower():
      print("Bot: Did you say that you want to learn how to use Proctorio?")
      user_input = input("You: ")
      if user_input.lower() == "yes":
        print("Bot: Please click on the following link (https://odl.utsa.edu/digital-tools/assessment/proctorio/), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "yup":
        print("Bot: Please click on the following link (https://odl.utsa.edu/digital-tools/assessment/proctorio/), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "yeah":
        print("Bot: Please click on the following link (https://odl.utsa.edu/digital-tools/assessment/proctorio/), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "affirmative":
        print("Bot: Please click on the following link (https://odl.utsa.edu/digital-tools/assessment/proctorio/), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "no":
        RandN = Save
        Good2L = Good2LBackup

    elif 'blackboard' in user_input.lower():
      print("Bot: Did you say that you want to learn how to use Blackboard?")
      user_input = input("You: ")
      if user_input.lower() == "yes":
        print("Bot: Please click on the following link (https://odl.utsa.edu/blackboard-collaborate/), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "yup":
        print("Bot: Please click on the following link (https://odl.utsa.edu/blackboard-collaborate/), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "yeah":
        print("Bot: Please click on the following link (https://odl.utsa.edu/blackboard-collaborate/), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "affirmative":
        print("Bot: Please click on the following link (https://odl.utsa.edu/blackboard-collaborate/), and after reading that material, please, confirm if I that was able to help you.")
      elif user_input.lower() == "no":
        RandN = Save
        Good2L = Good2LBackup

    user_input = input("You: ")
#This asks if i did a good job heping you resoind no and it resets you to the begining of the loop
    if 'yes' in user_input.lower():
        print("Bot: Anytime, Is there anything else i can do for you roday?")
    elif 'yup' in user_input.lower():
        print("Bot: No problem, Is there anything else i can do for you roday?")
    elif 'yeah' in user_input.lower():
        print("Bot: Thats great to heat, Is there anything else i can do for you roday?")
    elif 'affirmative' in user_input.lower():
        print("Bot: Glad i could help, Is there anything else i can do for you roday?")
    elif 'no' in user_input.lower():
        RandN = Save
        Good2L = Good2LBackup

#This is if you responded yes then it asks if you need anything else say yes and also get reset to the begining
    user_input = input("You: ")
    if 'negative' in user_input.lower():
        print("Bot: It's been a pleasure to help you. Have a nice day!")
    elif 'no' in user_input.lower():
        print("Bot: It's been a pleasure to help you. Have a nice day!")
    elif 'nope' in user_input.lower():
        print("Bot: It's been a pleasure to help you. Have a nice day!")
    elif 'nah' in user_input.lower():
        print("Bot: It's been a pleasure to help you. Have a nice day!")
    elif 'yes' in user_input.lower():
        RandN = Save
        Good2L = Good2LBackup
#this is the end where you can type your final response
    user_input = input("You: ")
    #kicks you out of the loop program is over
    ThirdL = 5
# Out:
# Bot: Hello, I'm UTS-Bot. I'll be happy to help you.
# You: hi
# Bot: How are you feeling today?
# You: good
# Bot: Awsome to hear. How can I help you today?
# You: Blackboard
# Bot: Did you say that you want to learn how to use Blackboard?
# You: yes
# Bot: Please click on the following link (https://odl.utsa.edu/blackboard-collaborate/), and after reading that material, please, confirm if I that was able to help you.
# You: yes
# Bot: Anytime, Is there anything else i can do for you roday?
# You: no
# Bot: It's been a pleasure to help you. Have a nice day!
# You: yeah
